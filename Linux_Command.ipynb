# %% [markdown]
# # Welcome to Colab!

# %%
# !mkdir AI_Project

# %%
# !pwd
# Out:
# /content

# %%
# !cd /content

# %%
# !mkdir datasets models notebooks scripts outputs

# %%
# !touch README.md requirements.txt

# %%
# !ls
# Out:
# AI_Project  drive   notebooks  ReadMe.md  requirements.txt  scripts
# datasets    models  outputs    README.md  sample_data	    student.csv

# %%
# !touch ReadMe.md

# %%
# !ls
# Out:
# AI_Project  models     outputs	  sample_data
# datasets    notebooks  ReadMe.md  scripts

# %%
# !echo "My first AI Project"> ReadMe.md

# %%
# !cat ReadMe.md
# Out:
# My first AI Project

# %%
# !cp ReadMe.md scripts/

# %%
# !ls scripts/

# %%
# !file ReadMe.md

# %%
# !echo "ID,Name,Marks" >> student.csv
# !echo "01,Maham,90" >> student.csv
# !echo "02,Musfeera,91" >> student.csv
# !echo "03,Zahida,92" >> student.csv
# !echo "04,Areesha,93" >> student.csv
# !echo "05,Tahreem,89" >> student.csv
# !echo "06,Noor,95" >> student.csv
# !echo "07,Ali,96" >> student.csv
# !echo "08,Arham,98" >> student.csv
# !echo "09,Husnain,99" >> student.csv
# !echo "10,Bilal,97" >> student.csv

# %%
# !head student.csv
# Out:
# ID,Name,Marks
# 01,Maham,90
# 02,Musfeera,91
# 03,Zahida,92
# 04,Areesha,93
# 05,Tahreem,89
# 06,Noor,95
# 07,Ali,96
# 08,Arham,98
# 09,Husnain,99

# %%
# !tail student.csv
# Out:
# 01,Maham,90
# 02,Musfeera,91
# 03,Zahida,92
# 04,Areesha,93
# 05,Tahreem,89
# 06,Noor,95
# 07,Ali,96
# 08,Arham,98
# 09,Husnain,99
# 10,Bilal,97

# %%
from google.colab import files
files.download('student.csv')
